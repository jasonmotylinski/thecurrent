# %%
import spotipy
from datetime import datetime
from dotenv import load_dotenv
from pipelines.thecurrent.playlist import get_hour_html, get_songs
from rawkit_playlist import playlist
from spotipy.oauth2 import SpotifyOAuth

PLAYLIST_ID="3PolUEn6bpV7PPQO8EKkAc"
load_dotenv()

# authenticating
scope = "playlist-modify-public playlist-modify-private user-library-read"
spotify = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))
# user ID for all user parameters in future functions
user = spotify.current_user()["id"]
# Out:
# DEBUG:spotipy.client:Sending GET to https://api.spotify.com/v1/me/ with Params: {} Headers: {'Authorization': 'Bearer BQCU_lA5BirEQE2c4G2-vNHlYrhvp4Tjt8R7rb9_OJiczyTZTNt4gzO_XO8n1k823uCG4WH2XXwsHi6Egeim-7VHYuw5jAHd7B4Fs2SV5gnVmC7db6idn-kU71DXIYx38aEnngayVBE2b-C1fcfM52NRn6FownQAujLqyBSpywcs0B_hGLeg3_OMncht3bz-RPIBX1FK6--B7Drvs8BhMim7gJiVWy3b6SkQil5rJXa-a2J_OBAf8_YrsZJMbk7QoE0', 'Content-Type': 'application/json'} and Body: None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.spotify.com:443
# DEBUG:urllib3.connectionpool:https://api.spotify.com:443 "GET /v1/me/ HTTP/1.1" 200 None
# DEBUG:spotipy.client:RESULTS: {'display_name': 'Jason', 'external_urls': {'spotify': 'https://open.spotify.com/user/12140608440'}, 'followers': {'href': None, 'total': 21}, 'href': 'https://api.spotify.com/v1/users/12140608440', 'id': '12140608440', 'images': [{'height': 300, 'url': 'https://i.scdn.co/image/ab6775700000ee85d34bfe13a1a149962d507a4b', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67757000003b82d34bfe13a1a149962d507a4b', 'width': 64}], 'type': 'user', 'uri': 'spotify:user:12140608440'}

# %%
def get_recent_songs():
    dte=datetime.now()
    year=dte.year
    month=dte.month
    day=dte.day
    hour=dte.hour-1

    html=get_hour_html(year, month, day, hour)
    return get_songs(html)

# %%
most_recent_played=list(get_recent_songs())[0]
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.thecurrent.org:443
# DEBUG:urllib3.connectionpool:https://www.thecurrent.org:443 "GET /playlist/2024-10-31/19 HTTP/1.1" 301 269
# DEBUG:urllib3.connectionpool:https://www.thecurrent.org:443 "GET /playlist/the-current/2024-10-31/19 HTTP/1.1" 200 None

# %%
spotify_details_for_most_recent_played=playlist.compile_track_ids([{"artist_name": most_recent_played['artist'], "song_name": most_recent_played["title"]}])[0]
# Out:
# DEBUG:spotipy.client:Sending GET to https://api.spotify.com/v1/search with Params: {'q': 'TV On The Radio,Wolf Like Me', 'limit': 10, 'offset': 0, 'type': 'track', 'market': None} Headers: {'Authorization': 'Bearer BQCU_lA5BirEQE2c4G2-vNHlYrhvp4Tjt8R7rb9_OJiczyTZTNt4gzO_XO8n1k823uCG4WH2XXwsHi6Egeim-7VHYuw5jAHd7B4Fs2SV5gnVmC7db6idn-kU71DXIYx38aEnngayVBE2b-C1fcfM52NRn6FownQAujLqyBSpywcs0B_hGLeg3_OMncht3bz-RPIBX1FK6--B7Drvs8BhMim7gJiVWy3b6SkQil5rJXa-a2J_OBAf8_YrsZJMbk7QoE0', 'Content-Type': 'application/json'} and Body: None
# DEBUG:urllib3.connectionpool:https://api.spotify.com:443 "GET /v1/search?q=TV+On+The+Radio%2CWolf+Like+Me&limit=10&offset=0&type=track HTTP/1.1" 200 None
# DEBUG:spotipy.client:RESULTS: {'tracks': {'href': 'https://api.spotify.com/v1/search?query=TV+On+The+Radio%2CWolf+Like+Me&type=track&offset=0&limit=10', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HJIB8sYPyxrFGuwvKXSLR'}, 'href': 'https://api.spotify.com/v1/artists/3HJIB8sYPyxrFGuwvKXSLR', 'id': '3HJIB8sYPyxrFGuwvKXSLR', 'name': 'TV On The Radio', 'type': 'artist', 'uri': 'spotify:artist:3HJIB8sYPyxrFGuwvKXSLR'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/4sD8WQQ8f1x3L4YFa9qFIO'}, 'href': 'https://api.spotify.com/v1/albums/4sD8WQQ8f1x3L4YFa9qFIO', 'id': '4sD8WQQ8f1x3L4YFa9qFIO', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2739a9c25a9f9f7adb419694a4b', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e029a9c25a9f9f7adb419694a4b', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048519a9c25a9f9f7adb419694a4b', 'width': 64}], 'name': 'Return To Cookie Mountain', 'release_date': '2006-07-03', 'release_date_precision': 'day', 'total_tracks': 11, 'type': 'album', 'uri': 'spotify:album:4sD8WQQ8f1x3L4YFa9qFIO'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HJIB8sYPyxrFGuwvKXSLR'}, 'href': 'https://api.spotify.com/v1/artists/3HJIB8sYPyxrFGuwvKXSLR', 'id': '3HJIB8sYPyxrFGuwvKXSLR', 'name': 'TV On The Radio', 'type': 'artist', 'uri': 'spotify:artist:3HJIB8sYPyxrFGuwvKXSLR'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 277466, 'explicit': False, 'external_ids': {'isrc': 'USTG30626805'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6Zgd7SomLTZkL1WPh4CUnV'}, 'href': 'https://api.spotify.com/v1/tracks/6Zgd7SomLTZ ...

# %%
last100playlist=spotify.playlist(PLAYLIST_ID)
# Out:
# DEBUG:spotipy.client:Sending GET to https://api.spotify.com/v1/playlists/3PolUEn6bpV7PPQO8EKkAc with Params: {'fields': None, 'market': None, 'additional_types': 'track'} Headers: {'Authorization': 'Bearer BQCU_lA5BirEQE2c4G2-vNHlYrhvp4Tjt8R7rb9_OJiczyTZTNt4gzO_XO8n1k823uCG4WH2XXwsHi6Egeim-7VHYuw5jAHd7B4Fs2SV5gnVmC7db6idn-kU71DXIYx38aEnngayVBE2b-C1fcfM52NRn6FownQAujLqyBSpywcs0B_hGLeg3_OMncht3bz-RPIBX1FK6--B7Drvs8BhMim7gJiVWy3b6SkQil5rJXa-a2J_OBAf8_YrsZJMbk7QoE0', 'Content-Type': 'application/json'} and Body: None
# DEBUG:urllib3.connectionpool:https://api.spotify.com:443 "GET /v1/playlists/3PolUEn6bpV7PPQO8EKkAc?additional_types=track HTTP/1.1" 200 None
# DEBUG:spotipy.client:RESULTS: {'collaborative': False, 'description': '', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/3PolUEn6bpV7PPQO8EKkAc'}, 'followers': {'href': None, 'total': 0}, 'href': 'https://api.spotify.com/v1/playlists/3PolUEn6bpV7PPQO8EKkAc?additional_types=track', 'id': '3PolUEn6bpV7PPQO8EKkAc', 'images': [{'height': None, 'url': 'https://i.scdn.co/image/ab67616d00001e029a9c25a9f9f7adb419694a4b', 'width': None}], 'name': 'The Current 89.3 Last 100 Played', 'owner': {'display_name': 'Jason', 'external_urls': {'spotify': 'https://open.spotify.com/user/12140608440'}, 'href': 'https://api.spotify.com/v1/users/12140608440', 'id': '12140608440', 'type': 'user', 'uri': 'spotify:user:12140608440'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAADFB6NQOwMsNH/Svm81jAshpiDaiB', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/3PolUEn6bpV7PPQO8EKkAc/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2024-11-01T00:32:24Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12140608440'}, 'href': 'https://api.spotify.com/v1/users/12140608440', 'id': '12140608440', 'type': 'user', 'uri': 'spotify:user:12140608440'}, 'is_local': False, 'primary_color': None, 'track': {'preview_url': 'https://p.scdn.co/mp3-preview/e74ea6618fc819d85300d9f94e50312ad3c951bd?cid=570577ec576c405aa89de88bfaf20288', 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'explicit': False, 'type': 'track', 'episode': False, 'track': True, 'album': {'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'type': 'album', 'album_type': 'album', 'href': 'https://api.spotify.com/v1/albums/4sD8WQQ8f1x3L4YFa9qFIO', 'id': '4sD8WQQ8f1x3L4YFa9qFIO', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739a9c25a9f9f7adb419694a4b', 'width': 640, 'height': 640}, { ...

# %%
def prune_playlist(pl):
    max_playlist_length=100
    print(pl['tracks']['items'][max_playlist_length-1]['track']['uri'])
    if len(pl['tracks']['items']) == max_playlist_length:
        spotify.playlist_remove_all_occurrences_of_items(playlist_id=pl['id'], items=[pl['tracks']['items'][max_playlist_length-1]['track']['uri']])

should_add=False

if len(last100playlist['tracks']['items']) > 0:
    if last100playlist['tracks']['items'][0]['track']['uri'] != spotify_details_for_most_recent_played:
        should_add=True
else:
    should_add=True

should_add=True # hack

if should_add:
    prune_playlist(last100playlist)
    spotify.playlist_add_items(playlist_id=PLAYLIST_ID,items=[spotify_details_for_most_recent_played],position=0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[146], line 18
#      15 should_add=True # hack
#      17 if should_add:
# ---> 18     prune_playlist(last100playlist)
#      19     spotify.playlist_add_items(playlist_id=PLAYLIST_ID,items=[spotify_details_for_most_recent_played],position=0)
#
# Cell In[146], line 3, in prune_playlist(pl)
#       1 def prune_playlist(pl):
#       2     max_playlist_length=4
# ----> 3     print(pl['tracks']['items'][max_playlist_length-1]['track']['uri'])
#       4     if len(pl['tracks']['items']) == max_playlist_length:
#       5         spotify.playlist_remove_all_occurrences_of_items(playlist_id=pl['id'], items=[pl['tracks']['items'][max_playlist_length-1]['track']['uri']])
#
# IndexError: list index out of range
