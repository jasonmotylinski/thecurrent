# %%
import config
from parsers.wfuv import WfuvParser

# %%
file_path="output/wfuv/json/by_day/2024/11/playlist_20241101.json"
with open(file_path, 'r') as file:  # 'r' is for read mode
    parser=WfuvParser(config.WFUV)
    parser.parse(file)
# Out:
# [
#     {
#         "command": "settings",
#         "settings": {
#             "pluralDelimiter": "\u0003",
#             "suppressDeprecationErrors": true,
#             "ajaxPageState": {
#                 "libraries": "eJxtjEEKgDAMBD9U7JNKglEiqZEmbdXXK1486GVhhmGR3Kkk2jc1GtPEcqNFqK7JKmb2gP_JTCsVkIAC5xGRdYAF9tCYusVnvyLrWIVCn2qLm8AhbP4ea8kXGCU4-w",
#                 "theme": "wfuv",
#                 "theme_token": null
#             },
#             "ajaxTrustedUrl": {
#                 "/playlist/feed": true
#             },
#             "views": {
#                 "ajax_path": "/views/ajax",
#                 "ajaxViews": {
#                     "views_dom_id:c116b6fcc43b259df5de1a0995caab29e177380a497590ff68b60514b0751add": {
#                         "view_name": "on_air_playlist",
#                         "view_display_id": "block_wfuv_on_air_playlist",
#                         "view_args": "",
#                         "view_path": "/views/ajax",
#                         "view_base_path": "playlist/feed",
#                         "view_dom_id": "c116b6fcc43b259df5de1a0995caab29e177380a497590ff68b60514b0751add",
#                         "pager_element": 0
#                     }
#                 }
#             },
#             "user": {
#                 "uid": 0,
#                 "permissionsHash": "bc7159b771f0c68113f79da62317dd853784a3075c254de8bca9598d358b2fc4"
#             }
#         },
#         "merge": true
#     },
#     {
#         "command": "add_css",
#         "data": [
#             {
#                 "rel": "stylesheet",
#                 "media": "all",
#                 "href": "/sites/default/files/css/css_P0NBRPequRlNPI_Fk8YIkgdp6jIMpQ1OeFmV8IMqffU.css?delta=0&language=en&theme=wfuv&include=eJx1iksOgCAMBS9E4EikxGpqijW0gHp6PxvduJnkzZtG2DW0mz7LUBldYjj2kEg8zLC59ikekdAMS8RtFcUhjsTX1DDhggX474ZqErWmTOb6WFtYGXYmtbeUkk_QQjj7"
#             },
#             {
#                 "rel": "stylesheet",
#                 "media": "all",
#                 "href": "/sites/default/files/css/css_BkotBItNpNsracIqGiD_h_SEXyxhyruZJ4ux7RENmbM.css?delta=1&language=en&theme=wfuv&include=eJx1iksOgCAMBS9E4EikxGpqijW0gHp6PxvduJnkzZtG2DW0mz7LUBldYjj2kEg8zLC59ikekdAMS8RtFcUhjsTX1DDhggX474ZqErWmTOb6WFtYGXYmtbeUkk_QQjj7"
#             }
#         ]
#     },
#     {
#         "command": "add_js",
#         "selector": "body",
#         "data": [
#             {
#                 "src": "/core/assets/vendor/jquery/jquery.min.js?v=3.7.1"
#             },
#             {
#                 "src": "/core/assets/vendor/once/once.min.js?v=1.0.1"
#             },
#             {
#                 "src": "/core/misc/drupalSettingsLoader.js?v=10.2.7"
#             },
#             {
#                 "src": "/core/misc/drupal.js?v=10.2.7"
#             },
#             {
#                 "src": "/core/misc/drupal.init.js?v=10.2.7"
#             },
#             {
#                 "src": "/core/misc/debounce.js?v=10.2.7"
#             },
#             {
#                 "src": "/libraries/dompurify/dist/purify.min.js?v=10.2.7"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/dblazy.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/plugin/blazy.once.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/plugin/blazy.sanitizer.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/plugin/blazy.dom.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/base/blazy.base.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/plugin/blazy.dataset.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/plugin/blazy.viewport.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/plugin/blazy.xlazy.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/plugin/blazy.observer.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/base/io/bio.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/base/io/bio.media.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/base/blazy.drupal.min.js?skzkzp"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/blazy.compat.min.js?skzkzp"
#             },
#             {
#                 "src": "/core/assets/vendor/tabbable/index.umd.min.js?v=6.2.0"
#             },
#             {
#                 "src": "/core/misc/progress.js?v=10.2.7"
#             },
#             {
#                 "src": "/core/assets/vendor/loadjs/loadjs.min.js?v=4.2.0"
#             },
#             {
#                 "src": "/core/misc/announce.js?v=10.2.7"
#             },
#             {
#                 "src": "/core/misc/message.js?v=10.2.7"
#             },
#             {
#                 "src": "/core/misc/ajax.js?v=10.2.7"
#             },
#             {
#                 "src": "/themes/contrib/stable/js/ajax.js?v=10.2.7"
#             },
#             {
#                 "src": "/modules/contrib/blazy/js/base/io/bio.ajax.min.js?skzkzp"
#             },
#             {
#                 "src": "/core/assets/vendor/jquery-form/jquery.form.min.js?v=4.3.0"
#             },
#             {
#                 "src": "/core/modules/views/js/base.js?v=10.2.7"
#             },
#             {
#                 "src": "/core/modules/views/js/ajax_view.js?v=10.2.7"
#             },
#             {
#                 "src": "/modules/contrib/better_exposed_filters/js/better_exposed_filters.js?v=6.x"
#             },
#             {
#                 "src": "/modules/contrib/better_exposed_filters/js/auto_submit.js?v=6.x"
#             },
#             {
#                 "src": "/themes/custom/wfuv/js/playlist_exposed_filters.js?v=10.2.7"
#             }
#         ]
#     },
#     {
#         "command": "insert",
#         "method": "replaceWith",
#         "selector": ".js-view-dom-id-",
#         "data": "\n<div class=\"view view-on-air-playlist view-id-on_air_playlist view-display-id-block_wfuv_on_air_playlist js-view-dom-id-c116b6fcc43b259df5de1a0995caab29e177380a497590ff68b60514b0751add\">\n  \n    \n  \n        <div class=\"view-filters view-with-ghost-date\">\n      <div class=\"row align-items-center\">\n        <div class=\"current_date col-12 col-lg mb-3 mb-lg-0\">\n           <h2 class=\"h3\">November 03, 2024 12:21 PM</h2>\n        </div>\n        <div class=\"col-12 col-lg-auto\">\n          <div class=\"row\">\n  <div class=\"d-block\">\n    <div class=\"container\">\n      <div class=\"col-12\">\n        <form class=\"views-exposed-form bef-exposed-form\" data-bef-auto-submit-full-form=\"\" data-bef-auto-submit=\"\" data-bef-auto-submit-delay=\"500\" data-drupal-selector=\"views-exposed-form-on-air-playlist-block-wfuv-on-air-playlist\" action=\"/playlist/feed\" method=\"get\" id=\"views-exposed-form-on-air-playlist-block-wfuv-on-air-playlist\" accept-charset=\"UTF-8\">\n          <div class=\"form--inline clearfix\">\n  <div data-drupal-selector=\"edit-created-wrapper\" id=\"edit-created-wrapper\" class=\"js-form-wrapper form-wrapper\"><fieldset data-drupal-selector=\"edit-created-wrapper\" id=\"edit-created-wrapper--2\" class=\"js-form-item form-item js-form-wrapper form-wrapper\">\n      <legend>\n    <span class=\"fieldset-legend\">Search by date</span>\n  </legend>\n  <div class=\"fieldset-wrapper\">\n                <div class=\"js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-created-min form-item-created-min\">\n      <label for=\"edit-created-min\">Min</label>\n        <input data-drupal-selector=\"edit-created-min\" type=\"text\" id=\"edit-created-min\" name=\"created[min]\" value=\"\" size=\"30\" maxlength=\"128\" class=\"form-text\" />\n\n        </div>\n<div class=\"js-form-item form-item js-form-type-textfield form-type-textfield js-form-item-created-max form-item-created-max\">\n      <label for=\"edit-created-max\">Max</label>\n        <input data-drupal-selector=\"edit-created-max\" type=\"text\" id=\"edit-created-max\" name=\"created[max]\" value=\"\" size=\"30\" maxlength=\"128\" class=\"form-text\" />\n\n        </div>\n\n          </div>\n</fieldset>\n</div>\n<div id=\"edit-created-ghost\" data-drupal-field-elements=\"date\" class=\"container-inline\">\n  <div class=\"js-form-item form-item js-form-type-date form-type-date js-form-item-created-ghost-date form-item-created-ghost-date form-no-label\">\n      <label for=\"edit-created-ghost-date\" class=\"visually-hidden\">Date</label>\n        <input data-bef-auto-submit-exclude data-drupal-selector=\"edit-created-ghost-date\" type=\"date\" placeholder=\"YYYY-MM-DD\" data-help=\"Enter the date using the format YYYY-MM-DD (e.g., 2024-11-03).\" id=\"edit-created-ghost-date\" name=\"created_ghost[date]\" value=\"\" size=\"12\" class=\"form-date\" />\n\n        </div>\n\n</div>\n\n<div data-drupal-selector=\"edit-actions\" class=\"form-actions js-form-wrapper form-wrapper\" id=\"edit-actions\"><input data-bef-auto-submit-click=\"\" class=\"js-hide button js-form-submit form-submit btn btn-secondary\" data-drupal-selector=\"edit-submit-on-air-playlist\" type=\"submit\" id=\"edit-submit-on-air-playlist\" value=\"Apply\" />\n</div>\n\n</div>\n\n        </form>\n      </div>\n    </div>\n  </div>\n</div>\n\n        </div>\n      </div>\n    </div>\n  \n  \n      <div class=\"view-content\">\n      <div class=\"table-responsive\">\n<table class=\"table table-striped views-table views-view-table cols-3\">\n        <thead class=\"table-dark\">\n      <tr>\n                                                  <th id=\"view-created-table-column\" class=\"views-field views-field-created\" scope=\"col\">Time</th>\n                                                  <th id=\"view-title-table-column\" class=\"views-field views-field-title\" scope=\"col\">Song Title</th>\n                                                  <t ...
#         "settings": null
#     },
#     {
#         "command": "insert",
#         "method": "prepend",
#         "selector": ".js-view-dom-id-",
#         "data": "",
#         "settings": null
#     }
# ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       3     contents = file.read()
#       5 parser=WfuvParser(config.WFUV)
# ----> 6 parser.parse(contents)
#
# File ~/code/personal/thecurrent/parsers/wfuv.py:11, in WfuvParser.parse(self, input)
#       9 def parse(self, input):
#      10     print(input)
# ---> 11     tbody=bs.BeautifulSoup(json.load(input)[4]['data']).select_one('tbody')
#      13     for tr in tbody.select('tr'):
#      14         dte=tr.find('td', {'headers': 'view-created-table-column'}).text.strip()
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# AttributeError: 'str' object has no attribute 'read'
