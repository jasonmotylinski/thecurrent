# %%
import config
import datetime
import json
from parsers.wfmu import WfmuParser

parser = WfmuParser(config=config)

print(json.dumps(list(parser.get_songs(date=datetime.date(2025, 12, 25))), indent=2))
# Out:
# {'month': '12', 'day': '25', 'year': '2025', 'hour_12': '1', 'minute': '00', 'meridian': 'am', 'submit': 'Find the song or show!'}
# [
#   {
#     "song": "Ahmedabab Theme",
#     "artist": "Jack Arel & Jean-Claude Petit",
#     "played_at": "2025-12-25T12:57:00-05:00",
#     "album": null
#   },
#   {
#     "song": "Black Sand",
#     "artist": "Brainticket",
#     "played_at": "2025-12-25T13:00:00-05:00",
#     "album": null
#   },
#   {
#     "song": "Hells Angels On Wheels",
#     "artist": "Stu Phillips",
#     "played_at": "2025-12-25T13:00:00-05:00",
#     "album": null
#   },
#   {
#     "song": "The Lady Rachel",
#     "artist": "Kevin Ayers",
#     "played_at": "2025-12-25T13:00:00-05:00",
#     "album": null
#   },
#   {
#     "song": "Everything is One big Christmas Tree",
#     "artist": "Magnetic Fields",
#     "played_at": "2025-12-25T13:02:00-05:00",
#     "album": "Realism"
#   }
# ]
